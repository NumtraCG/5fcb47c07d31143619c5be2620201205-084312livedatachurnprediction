# %% [markdown]
# ***GENERATED CODE FOR livedatachurnprediction PIPELINE.***

# %% [markdown]
# ***DON'T EDIT THIS CODE.***

# %% [markdown]
# ***CONNECTOR FUNCTIONS TO READ DATA.***

# %% [markdown]
# ***TRANSFORMATIONS FUNCTIONS THAT WILL BE APPLIED ON DATA***

# %%
import json
from pyspark.sql.types import IntegerType
from pyspark.ml.feature import StringIndexer
from pyspark.sql.functions import col, when
from pyspark.sql.types import IntegerType
from pyspark.sql.functions import mean, stddev, min, max, col


class CleanseData:
    # def __init__(self,df):
    #     #print()

    def replaceByMean(self, feature, df, mean_=-1):

        meanValue = df.select(mean(col(feature.name)).alias(
            'mean')).collect()[0]["mean"]
        df.fillna(meanValue, subset=[feature.name])
        df.withColumn(feature.name, when(col(feature.name) == " ",
                                         meanValue).otherwise(col(feature.name).cast("Integer")))
        return df

    def replaceByMax(self, feature, df, max_=-1):
        maxValue = df.select(max(col(feature.name)).alias('max')).collect()[
            0]["max"]
        df.fillna(maxValue, subset=[feature.name])
        df = df.withColumn(feature.name,
                           when(col(feature.name) == " ", maxValue).otherwise(col(feature.name)))
        return df

    def replaceByMin(self, feature, df, min_=-1):
        minValue = df.select(min(col(feature.name)).alias('min')).collect()[
            0]["min"]
        df.fillna(minValue, subset=[feature.name])
        df = df.withColumn(feature.name,
                           when(col(feature.name) == " ", minValue).otherwise(col(feature.name)))
        return df

    def replaceByStandardDeviation(self, feature, df, stddev_=-1):
        stddevValue = df.select(stddev(col(feature.name)).alias(
            'stddev')).collect()[0]["stddev"]
        df.fillna(stddevValue, subset=[feature.name])
        df = df.withColumn(feature.name,
                           when(col(feature.name) == " ", stddevValue).otherwise(col(feature.name)))
        return df

    def replaceDateRandomly(self, feature, df):
        fillValue = df.where(col(feature.name).isNotNull()
                             ).head(1)[0][feature.name]
        df.fillna(str(fillValue), subset=[feature.name])
        df = df.withColumn(feature.name,
                           when(col(feature.name) == " ", fillValue).otherwise(col(feature.name)))
        # print("CleanseData:replaceDateRandomly Schema : ", df.#printSchema())
        return df

    def replaceNullValues(self, fList, df):
        featuresList = df.schema.fields
        for featureObj in fList:
            for feat in featuresList:
                if featureObj["feature"] in feat.name:
                    featureName = feat
                    if "mean" in featureObj["replaceby"]:
                        df = self.replaceByMean(featureName, df)
                    elif "max" in featureObj["replaceby"]:
                        df = self.replaceByMax(featureName, df)
                    elif "min" in featureObj["replaceby"]:
                        df = self.replaceByMin(featureName, df)
                    elif "stddev" in featureObj["replaceby"]:
                        df = self.replaceByStandardDeviation(featureName, df)
                    elif "random" in featureObj["replaceby"]:
                        df = self.replaceDateRandomly(featureName, df)
        return df


def StringIndexerTransform(df, params, transformationData={}):
    dfReturn = df
    feature = params["feature"]

    dfReturn = dfReturn.fillna({feature: ''})
    outcol = feature + "_stringindexer"
    indexer = StringIndexer(
        inputCol=feature, outputCol=outcol, handleInvalid="skip")
    indexed = indexer.fit(dfReturn).transform(dfReturn)
    dfReturn = indexed
    distinct_values_list = dfReturn.select(
        outcol).distinct().rdd.map(lambda r: r[0]).collect()
    len_distinct_values_list = len(distinct_values_list)
    if len_distinct_values_list <= 4:
        changed_type_df = dfReturn.withColumn(
            outcol, dfReturn[outcol].cast(IntegerType()))
        return changed_type_df
    return dfReturn


class TransformationMain:
    # TODO: change df argument in run with following
    def run(transformationDF, config):
        configObj = json.loads(config)
        featureData = configObj["FE"]
        transformationDF = CleanseData().replaceNullValues(featureData, transformationDF)
        transformationDF = StringIndexerTransform(transformationDF, {'transformationsData': [{'feature_label': 'STATUS', 'transformation_label': 'String Indexer'}], 'feature': 'STATUS', 'type': 'string', 'selected': 'True', 'replaceby': 'max', 'stats': {
                                                  'count': '302', 'mean': '', 'stddev': '', 'min': 'A', 'max': 'I', 'missing': '0'}, 'transformation': [{'transformation': 'String Indexer', 'selectedAsDefault': 1}], 'updatedLabel': 'STATUS'}, {'feature_label': 'STATUS', 'transformation_label': 'String Indexer'})
        transformationDF = transformationDF.drop('STATUS')
        transformationDF = StringIndexerTransform(transformationDF, {'transformationsData': [{'feature_label': 'LAST_UPD_BY', 'transformation_label': 'String Indexer'}], 'feature': 'LAST_UPD_BY', 'type': 'string', 'selected': 'True', 'replaceby': 'max', 'stats': {
            'count': '302', 'mean': '1519.87', 'stddev': '460.48', 'min': '1646', 'max': 'Others', 'missing': '0'}, 'transformation': [{'transformation': 'String Indexer', 'selectedAsDefault': 1}], 'updatedLabel': 'LAST_UPD_BY'}, {'feature_label': 'LAST_UPD_BY', 'transformation_label': 'String Indexer'})
        transformationDF = transformationDF.drop('LAST_UPD_BY')
        transformationDF = StringIndexerTransform(transformationDF, {'transformationsData': [{'feature_label': 'STATE', 'transformation_label': 'String Indexer'}], 'feature': 'STATE', 'type': 'string', 'selected': 'True', 'replaceby': 'max', 'stats': {
            'count': '302', 'mean': '', 'stddev': '', 'min': 'Central Region', 'max': 'Western Region', 'missing': '0'}, 'transformation': [{'transformation': 'String Indexer', 'selectedAsDefault': 1}], 'updatedLabel': 'STATE'}, {'feature_label': 'STATE', 'transformation_label': 'String Indexer'})
        transformationDF = transformationDF.drop('STATE')
        transformationDF = StringIndexerTransform(transformationDF, {'transformationsData': [{'feature_label': 'COUNTRY', 'transformation_label': 'String Indexer'}], 'feature': 'COUNTRY', 'type': 'string', 'selected': 'True', 'replaceby': 'max', 'stats': {
            'count': '302', 'mean': '', 'stddev': '', 'min': 'Others', 'max': 'Tanzania', 'missing': '0'}, 'transformation': [{'transformation': 'String Indexer', 'selectedAsDefault': 1}], 'updatedLabel': 'COUNTRY'}, {'feature_label': 'COUNTRY', 'transformation_label': 'String Indexer'})
        transformationDF = transformationDF.drop('COUNTRY')
        transformationDF = StringIndexerTransform(transformationDF, {'transformationsData': [{'feature_label': 'DISTRICT', 'transformation_label': 'String Indexer'}], 'feature': 'DISTRICT', 'type': 'string', 'selected': 'True', 'replaceby': 'max', 'stats': {
            'count': '302', 'mean': '', 'stddev': '', 'min': 'Dar Es Salaam', 'max': 'Others', 'missing': '0'}, 'transformation': [{'transformation': 'String Indexer', 'selectedAsDefault': 1}], 'updatedLabel': 'DISTRICT'}, {'feature_label': 'DISTRICT', 'transformation_label': 'String Indexer'})
        transformationDF = transformationDF.drop('DISTRICT')
        transformationDF = StringIndexerTransform(transformationDF, {'transformationsData': [{'feature_label': 'COMPLAINTS_COUNT', 'transformation_label': 'String Indexer'}], 'feature': 'COMPLAINTS_COUNT', 'type': 'string', 'selected': 'True', 'replaceby': 'max', 'stats': {
            'count': '302', 'mean': '', 'stddev': '', 'min': '(0.0, 5.0]', 'max': '(5.0, 10.0]', 'missing': '0'}, 'transformation': [{'transformation': 'String Indexer', 'selectedAsDefault': 1}], 'updatedLabel': 'COMPLAINTS_COUNT'}, {'feature_label': 'COMPLAINTS_COUNT', 'transformation_label': 'String Indexer'})
        transformationDF = transformationDF.drop('COMPLAINTS_COUNT')
        transformationDF = StringIndexerTransform(transformationDF, {'transformationsData': [{'feature_label': 'DATE_DIFF_FIRST_COMPLAINT', 'transformation_label': 'String Indexer'}], 'feature': 'DATE_DIFF_FIRST_COMPLAINT', 'type': 'string', 'selected': 'True', 'replaceby': 'max', 'stats': {
            'count': '302', 'mean': '', 'stddev': '', 'min': '(-1.0, 0.0]', 'max': '(50.0, 100.0]', 'missing': '0'}, 'transformation': [{'transformation': 'String Indexer', 'selectedAsDefault': 1}], 'updatedLabel': 'DATE_DIFF_FIRST_COMPLAINT'}, {'feature_label': 'DATE_DIFF_FIRST_COMPLAINT', 'transformation_label': 'String Indexer'})
        transformationDF = transformationDF.drop(
            'DATE_DIFF_FIRST_COMPLAINT')
        transformationDF = StringIndexerTransform(transformationDF, {'transformationsData': [{'feature_label': 'CUSTOMER_AGE', 'transformation_label': 'String Indexer'}], 'feature': 'CUSTOMER_AGE', 'type': 'string', 'selected': 'True', 'replaceby': 'max', 'stats': {
            'count': '302', 'mean': '', 'stddev': '', 'min': '(180, 360]', 'max': '(90, 180]', 'missing': '0'}, 'transformation': [{'transformation': 'String Indexer', 'selectedAsDefault': 1}], 'updatedLabel': 'CUSTOMER_AGE'}, {'feature_label': 'CUSTOMER_AGE', 'transformation_label': 'String Indexer'})
        transformationDF = transformationDF.drop('CUSTOMER_AGE')
        transformationDF = StringIndexerTransform(transformationDF, {'transformationsData': [{'feature_label': 'NUMBER_OF_1M_PLANS', 'transformation_label': 'String Indexer'}], 'feature': 'NUMBER_OF_1M_PLANS', 'type': 'string', 'selected': 'True', 'replaceby': 'max', 'stats': {
            'count': '302', 'mean': '', 'stddev': '', 'min': '(0, 2]', 'max': '(5.0, 10.0]', 'missing': '0'}, 'transformation': [{'transformation': 'String Indexer', 'selectedAsDefault': 1}], 'updatedLabel': 'NUMBER_OF_1M_PLANS'}, {'feature_label': 'NUMBER_OF_1M_PLANS', 'transformation_label': 'String Indexer'})
        transformationDF = transformationDF.drop('NUMBER_OF_1M_PLANS')
        transformationDF = StringIndexerTransform(transformationDF, {'transformationsData': [{'feature_label': 'TOTAL_RENEWALS_MONTHLY', 'transformation_label': 'String Indexer'}], 'feature': 'TOTAL_RENEWALS_MONTHLY', 'type': 'string', 'selected': 'True', 'replaceby': 'max', 'stats': {
            'count': '302', 'mean': '', 'stddev': '', 'min': '(0.0, 2.0]', 'max': '(5.0, 10.0]', 'missing': '0'}, 'transformation': [{'transformation': 'String Indexer', 'selectedAsDefault': 1}], 'updatedLabel': 'TOTAL_RENEWALS_MONTHLY'}, {'feature_label': 'TOTAL_RENEWALS_MONTHLY', 'transformation_label': 'String Indexer'})
        transformationDF = transformationDF.drop('TOTAL_RENEWALS_MONTHLY')
        transformationDF = StringIndexerTransform(transformationDF, {'transformationsData': [{'feature_label': 'TOTAL_RENEWALS_WEEKLY', 'transformation_label': 'String Indexer'}], 'feature': 'TOTAL_RENEWALS_WEEKLY', 'type': 'string', 'selected': 'True', 'replaceby': 'max', 'stats': {
            'count': '302', 'mean': '', 'stddev': '', 'min': '(-1, 0]', 'max': '(5, 10]', 'missing': '0'}, 'transformation': [{'transformation': 'String Indexer', 'selectedAsDefault': 1}], 'updatedLabel': 'TOTAL_RENEWALS_WEEKLY'}, {'feature_label': 'TOTAL_RENEWALS_WEEKLY', 'transformation_label': 'String Indexer'})
        transformationDF = transformationDF.drop('TOTAL_RENEWALS_WEEKLY')
        transformationDF = StringIndexerTransform(transformationDF, {'transformationsData': [{'feature_label': 'TOTAL_TOPUPS_MONTHLY', 'transformation_label': 'String Indexer'}], 'feature': 'TOTAL_TOPUPS_MONTHLY', 'type': 'string', 'selected': 'True', 'replaceby': 'max', 'stats': {
            'count': '302', 'mean': '', 'stddev': '', 'min': '(-1, 0]', 'max': '(5, 10]', 'missing': '0'}, 'transformation': [{'transformation': 'String Indexer', 'selectedAsDefault': 1}], 'updatedLabel': 'TOTAL_TOPUPS_MONTHLY'}, {'feature_label': 'TOTAL_TOPUPS_MONTHLY', 'transformation_label': 'String Indexer'})
        transformationDF = transformationDF.drop('TOTAL_TOPUPS_MONTHLY')
        transformationDF = StringIndexerTransform(transformationDF, {'transformationsData': [{'feature_label': 'HAVING_TOPUP', 'transformation_label': 'String Indexer'}], 'feature': 'HAVING_TOPUP', 'type': 'string', 'selected': 'True', 'replaceby': 'max', 'stats': {
            'count': '302', 'mean': '', 'stddev': '', 'min': 'N', 'max': 'Y', 'missing': '0'}, 'transformation': [{'transformation': 'String Indexer', 'selectedAsDefault': 1}], 'updatedLabel': 'HAVING_TOPUP'}, {'feature_label': 'HAVING_TOPUP', 'transformation_label': 'String Indexer'})
        transformationDF = transformationDF.drop('HAVING_TOPUP')
        transformationDF = StringIndexerTransform(transformationDF, {'transformationsData': [{'feature_label': 'OPENTITY_TYPE', 'transformation_label': 'String Indexer'}], 'feature': 'OPENTITY_TYPE', 'type': 'string', 'selected': 'True', 'replaceby': 'max', 'stats': {
            'count': '302', 'mean': '', 'stddev': '', 'min': 'CA', 'max': 'COS', 'missing': '0'}, 'transformation': [{'transformation': 'String Indexer', 'selectedAsDefault': 1}], 'updatedLabel': 'OPENTITY_TYPE'}, {'feature_label': 'OPENTITY_TYPE', 'transformation_label': 'String Indexer'})
        transformationDF = transformationDF.drop('OPENTITY_TYPE')
        display(transformationDF.limit(2).toPandas())
        return transformationDF

# %% [markdown]
# ***AUTOML FUNCTIONS***

# %%
from tpot import TPOTClassifier
from sklearn.model_selection import train_test_split
import pyspark


def functionClassification(sparkDF, listOfFeatures, label):
    sparkDF.persist(pyspark.StorageLevel.MEMORY_AND_DISK)
    df = (sparkDF.toPandas())
    X = (df.drop(label, axis=1))[listOfFeatures].values
    y = df[label].values
    X_train, X_test, y_train, y_test = train_test_split(
        X, y, random_state=1, test_size=0.1)
    tpotModel = TPOTClassifier(verbosity=3, n_jobs=-1, generations=10, max_time_mins=5,
                               population_size=15)
    tpotModel.fit(X_train, y_train)
    display(" Accuracy of Model : %s" % tpotModel.score(X_test, y_test))
    data = {'model': tpotModel,
            'X_test': X_test,
            'y_test': y_test,
            'label': label,
            'columnNames': listOfFeatures}
    return data

# %% [markdown]
# ***READING DATAFRAME***

# %%
from pyspark.sql import SparkSession
spark = SparkSession.builder.getOrCreate()

#%run livedatachurnpredictionHooks.ipynb
try:
	#sourcePreExecutionHook()

	livedatacustomerssample500005122020 = HDFSConnector.fetch(spark, "{'is_header': 'Use Header Line', 'fileType': 'Delimeted', 'domain': 'http://35.230.65.179', 'baseType': 'hdfs', 'url': '/FileStore/platform/uploadedSourceFiles/live_data_customers_sample_5000_05122020.csv', 'filename': 'live_data_customers_sample_5000_05122020.csv', 'token': '1', 'delimiter': ','}")

except Exception as ex: 
	logging.error(ex)

# %% [markdown]
# ***TRANSFORMING DATAFRAME***

# %%
#%run livedatachurnpredictionHooks.ipynb
try:
	#transformationPreExecutionHook()

	autofe = TransformationMain.run(livedatacustomerssample500005122020,json.dumps( {"FE": [{"transformationsData": [{"transformation_label": "novalue"}], "feature": "CUSTOMER_ID", "transformation": [{"transformation": "novalue", "selectedAsDefault": 1}], "type": "numeric", "replaceby": "mean", "selected": "True", "stats": {"count": "302", "mean": "1384516.1", "stddev": "62414.75", "min": "1288536", "max": "1530587", "missing": "0"}, "updatedLabel": "CUSTOMER_ID"}, {"transformationsData": [{"feature_label": "STATUS", "transformation_label": "String Indexer"}], "feature": "STATUS", "type": "string", "selected": "True", "replaceby": "max", "stats": {"count": "302", "mean": "", "stddev": "", "min": "A", "max": "I", "missing": "0"}, "transformation": [{"transformation": "String Indexer", "selectedAsDefault": 1}], "updatedLabel": "STATUS"}, {"transformationsData": [{"feature_label": "LAST_UPD_BY", "transformation_label": "String Indexer"}], "feature": "LAST_UPD_BY", "type": "string", "selected": "True", "replaceby": "max", "stats": {"count": "302", "mean": "1519.87", "stddev": "460.48", "min": "1646", "max": "Others", "missing": "0"}, "transformation": [{"transformation": "String Indexer", "selectedAsDefault": 1}], "updatedLabel": "LAST_UPD_BY"}, {"transformationsData": [{"feature_label": "STATE", "transformation_label": "String Indexer"}], "feature": "STATE", "type": "string", "selected": "True", "replaceby": "max", "stats": {"count": "302", "mean": "", "stddev": "", "min": "Central Region", "max": "Western Region", "missing": "0"}, "transformation": [{"transformation": "String Indexer", "selectedAsDefault": 1}], "updatedLabel": "STATE"}, {"transformationsData": [{"feature_label": "COUNTRY", "transformation_label": "String Indexer"}], "feature": "COUNTRY", "type": "string", "selected": "True", "replaceby": "max", "stats": {"count": "302", "mean": "", "stddev": "", "min": "Others", "max": "Tanzania", "missing": "0"}, "transformation": [{"transformation": "String Indexer", "selectedAsDefault": 1}], "updatedLabel": "COUNTRY"}, {"transformationsData": [{"feature_label": "DISTRICT", "transformation_label": "String Indexer"}], "feature": "DISTRICT", "type": "string", "selected": "True", "replaceby": "max", "stats": {"count": "302", "mean": "", "stddev": "", "min": "Dar Es Salaam", "max": "Others", "missing": "0"}, "transformation": [{"transformation": "String Indexer", "selectedAsDefault": 1}], "updatedLabel": "DISTRICT"}, {"transformationsData": [{"feature_label": "COMPLAINTS_COUNT", "transformation_label": "String Indexer"}], "feature": "COMPLAINTS_COUNT", "type": "string", "selected": "True", "replaceby": "max", "stats": {"count": "302", "mean": "", "stddev": "", "min": "(0.0, 5.0]", "max": "(5.0, 10.0]", "missing": "0"}, "transformation": [{"transformation": "String Indexer", "selectedAsDefault": 1}], "updatedLabel": "COMPLAINTS_COUNT"}, {"transformationsData": [{"feature_label": "DATE_DIFF_FIRST_COMPLAINT", "transformation_label": "String Indexer"}], "feature": "DATE_DIFF_FIRST_COMPLAINT", "type": "string", "selected": "True", "replaceby": "max", "stats": {"count": "302", "mean": "", "stddev": "", "min": "(-1.0, 0.0]", "max": "(50.0, 100.0]", "missing": "0"}, "transformation": [{"transformation": "String Indexer", "selectedAsDefault": 1}], "updatedLabel": "DATE_DIFF_FIRST_COMPLAINT"}, {"transformationsData": [{"transformation_label": "novalue"}], "feature": "CHURN_STATUS", "type": "real", "selected": "True", "replaceby": "mean", "stats": {"count": "302", "mean": "0.63", "stddev": "0.48", "min": "0.0", "max": "1.0", "missing": "0"}, "transformation": [{"transformation": "novalue", "selectedAsDefault": 1}], "updatedLabel": "CHURN_STATUS"}, {"transformationsData": [{"feature_label": "CUSTOMER_AGE", "transformation_label": "String Indexer"}], "feature": "CUSTOMER_AGE", "type": "string", "selected": "True", "replaceby": "max", "stats": {"count": "302", "mean": "", "stddev": "", "min": "(180, 360]", "max": "(90, 180]", "missing": "0"}, "transformation": [{"transformation": "String Indexer", "selectedAsDefault": 1}], "updatedLabel": "CUSTOMER_AGE"}, {"transformationsData": [{"feature_label": "NUMBER_OF_1M_PLANS", "transformation_label": "String Indexer"}], "feature": "NUMBER_OF_1M_PLANS", "type": "string", "selected": "True", "replaceby": "max", "stats": {"count": "302", "mean": "", "stddev": "", "min": "(0, 2]", "max": "(5.0, 10.0]", "missing": "0"}, "transformation": [{"transformation": "String Indexer", "selectedAsDefault": 1}], "updatedLabel": "NUMBER_OF_1M_PLANS"}, {"transformationsData": [{"feature_label": "TOTAL_RENEWALS_MONTHLY", "transformation_label": "String Indexer"}], "feature": "TOTAL_RENEWALS_MONTHLY", "type": "string", "selected": "True", "replaceby": "max", "stats": {"count": "302", "mean": "", "stddev": "", "min": "(0.0, 2.0]", "max": "(5.0, 10.0]", "missing": "0"}, "transformation": [{"transformation": "String Indexer", "selectedAsDefault": 1}], "updatedLabel": "TOTAL_RENEWALS_MONTHLY"}, {"transformationsData": [{"feature_label": "TOTAL_RENEWALS_WEEKLY", "transformation_label": "String Indexer"}], "feature": "TOTAL_RENEWALS_WEEKLY", "type": "string", "selected": "True", "replaceby": "max", "stats": {"count": "302", "mean": "", "stddev": "", "min": "(-1, 0]", "max": "(5, 10]", "missing": "0"}, "transformation": [{"transformation": "String Indexer", "selectedAsDefault": 1}], "updatedLabel": "TOTAL_RENEWALS_WEEKLY"}, {"transformationsData": [{"feature_label": "TOTAL_TOPUPS_MONTHLY", "transformation_label": "String Indexer"}], "feature": "TOTAL_TOPUPS_MONTHLY", "type": "string", "selected": "True", "replaceby": "max", "stats": {"count": "302", "mean": "", "stddev": "", "min": "(-1, 0]", "max": "(5, 10]", "missing": "0"}, "transformation": [{"transformation": "String Indexer", "selectedAsDefault": 1}], "updatedLabel": "TOTAL_TOPUPS_MONTHLY"}, {"transformationsData": [{"feature_label": "HAVING_TOPUP", "transformation_label": "String Indexer"}], "feature": "HAVING_TOPUP", "type": "string", "selected": "True", "replaceby": "max", "stats": {"count": "302", "mean": "", "stddev": "", "min": "N", "max": "Y", "missing": "0"}, "transformation": [{"transformation": "String Indexer", "selectedAsDefault": 1}], "updatedLabel": "HAVING_TOPUP"}, {"transformationsData": [{"transformation_label": "novalue"}], "feature": "DAILY_AVG_SPENDING", "type": "real", "selected": "True", "replaceby": "mean", "stats": {"count": "302", "mean": "491.93", "stddev": "194.53", "min": "78.76712328767123", "max": "1137.9310344827584", "missing": "0"}, "transformation": [{"transformation": "novalue", "selectedAsDefault": 1}], "updatedLabel": "DAILY_AVG_SPENDING"}, {"transformationsData": [{"feature_label": "OPENTITY_TYPE", "transformation_label": "String Indexer"}], "feature": "OPENTITY_TYPE", "type": "string", "selected": "True", "replaceby": "max", "stats": {"count": "302", "mean": "", "stddev": "", "min": "CA", "max": "COS", "missing": "0"}, "transformation": [{"transformation": "String Indexer", "selectedAsDefault": 1}], "updatedLabel": "OPENTITY_TYPE"}, {"transformationsData": [{"transformation_label": "novalue"}], "feature": "CA", "transformation": [{"transformation": "novalue", "selectedAsDefault": 1}], "type": "numeric", "replaceby": "mean", "selected": "True", "stats": {"count": "302", "mean": "0.45", "stddev": "0.5", "min": "0", "max": "1", "missing": "0"}, "updatedLabel": "CA"}, {"transformationsData": [{"transformation_label": "novalue"}], "feature": "CQ", "transformation": [{"transformation": "novalue", "selectedAsDefault": 1}], "type": "numeric", "replaceby": "mean", "selected": "True", "stats": {"count": "302", "mean": "0.0", "stddev": "0.0", "min": "0", "max": "0", "missing": "0"}, "updatedLabel": "CQ"}, {"transformationsData": [{"transformation_label": "novalue"}], "feature": "OP", "transformation": [{"transformation": "novalue", "selectedAsDefault": 1}], "type": "numeric", "replaceby": "mean", "selected": "True", "stats": {"count": "302", "mean": "0.98", "stddev": "0.15", "min": "0", "max": "1", "missing": "0"}, "updatedLabel": "OP"}, {"transformationsData": [{"transformation_label": "novalue"}], "feature": "PO", "transformation": [{"transformation": "novalue", "selectedAsDefault": 1}], "type": "numeric", "replaceby": "mean", "selected": "True", "stats": {"count": "302", "mean": "0.0", "stddev": "0.0", "min": "0", "max": "0", "missing": "0"}, "updatedLabel": "PO"}, {"transformationsData": [{"transformation_label": "novalue"}], "feature": "BI _ Azam English Service Group", "transformation": [{"transformation": "novalue", "selectedAsDefault": 1}], "type": "numeric", "replaceby": "mean", "selected": "True", "stats": {"count": "302", "mean": "0.0", "stddev": "0.0", "min": "0", "max": "0", "missing": "0"}, "updatedLabel": "BI _ Azam English Service..."}, {"transformationsData": [{"transformation_label": "novalue"}], "feature": "BI _ Plus Group", "transformation": [{"transformation": "novalue", "selectedAsDefault": 1}], "type": "numeric", "replaceby": "mean", "selected": "True", "stats": {"count": "302", "mean": "0.0", "stddev": "0.0", "min": "0", "max": "0", "missing": "0"}, "updatedLabel": "BI _ Plus Group"}, {"transformationsData": [{"transformation_label": "novalue"}], "feature": "BI _ Pure Group", "transformation": [{"transformation": "novalue", "selectedAsDefault": 1}], "type": "numeric", "replaceby": "mean", "selected": "True", "stats": {"count": "302", "mean": "0.0", "stddev": "0.0", "min": "0", "max": "0", "missing": "0"}, "updatedLabel": "BI _ Pure Group"}, {"transformationsData": [{"transformation_label": "novalue"}], "feature": "BI Azam Cloud Plus Addon Group", "transformation": [{"transformation": "novalue", "selectedAsDefault": 1}], "type": "numeric", "replaceby": "mean", "selected": "True", "stats": {"count": "302", "mean": "0.0", "stddev": "0.0", "min": "0", "max": "0", "missing": "0"}, "updatedLabel": "BI Azam Cloud Plus Addon ..."}, {"transformationsData": [{"transformation_label": "novalue"}], "feature": "FTA", "transformation": [{"transformation": "novalue", "selectedAsDefault": 1}], "type": "numeric", "replaceby": "mean", "selected": "True", "stats": {"count": "302", "mean": "0.05", "stddev": "0.22", "min": "0", "max": "1", "missing": "0"}, "updatedLabel": "FTA"}, {"transformationsData": [{"transformation_label": "novalue"}], "feature": "KE _ Azam Demo Group", "transformation": [{"transformation": "novalue", "selectedAsDefault": 1}], "type": "numeric", "replaceby": "mean", "selected": "True", "stats": {"count": "302", "mean": "0.0", "stddev": "0.0", "min": "0", "max": "0", "missing": "0"}, "updatedLabel": "KE _ Azam Demo Group"}, {"transformationsData": [{"transformation_label": "novalue"}], "feature": "KE _ Azam Plus Service Group", "transformation": [{"transformation": "novalue", "selectedAsDefault": 1}], "type": "numeric", "replaceby": "mean", "selected": "True", "stats": {"count": "302", "mean": "0.0", "stddev": "0.0", "min": "0", "max": "0", "missing": "0"}, "updatedLabel": "KE _ Azam Plus Service Gr..."}, {"transformationsData": [{"transformation_label": "novalue"}], "feature": "KE _ Azam Pure Service Group", "transformation": [{"transformation": "novalue", "selectedAsDefault": 1}], "type": "numeric", "replaceby": "mean", "selected": "True", "stats": {"count": "302", "mean": "0.0", "stddev": "0.0", "min": "0", "max": "0", "missing": "0"}, "updatedLabel": "KE _ Azam Pure Service Gr..."}, {"transformationsData": [{"transformation_label": "novalue"}], "feature": "KE Azam Cloud Plus Addon Group", "transformation": [{"transformation": "novalue", "selectedAsDefault": 1}], "type": "numeric", "replaceby": "mean", "selected": "True", "stats": {"count": "302", "mean": "0.0", "stddev": "0.0", "min": "0", "max": "0", "missing": "0"}, "updatedLabel": "KE Azam Cloud Plus Addon ..."}, {"transformationsData": [{"transformation_label": "novalue"}], "feature": "MW _ Azam Play Service Group", "transformation": [{"transformation": "novalue", "selectedAsDefault": 1}], "type": "numeric", "replaceby": "mean", "selected": "True", "stats": {"count": "302", "mean": "0.0", "stddev": "0.0", "min": "0", "max": "0", "missing": "0"}, "updatedLabel": "MW _ Azam Play Service Gr..."}, {"transformationsData": [{"transformation_label": "novalue"}], "feature": "MW _ Azam Plus Service Group", "transformation": [{"transformation": "novalue", "selectedAsDefault": 1}], "type": "numeric", "replaceby": "mean", "selected": "True", "stats": {"count": "302", "mean": "0.0", "stddev": "0.0", "min": "0", "max": "0", "missing": "0"}, "updatedLabel": "MW _ Azam Plus Service Gr..."}, {"transformationsData": [{"transformation_label": "novalue"}], "feature": "MW _ Azam Pure Service Group", "transformation": [{"transformation": "novalue", "selectedAsDefault": 1}], "type": "numeric", "replaceby": "mean", "selected": "True", "stats": {"count": "302", "mean": "0.0", "stddev": "0.0", "min": "0", "max": "0", "missing": "0"}, "updatedLabel": "MW _ Azam Pure Service Gr..."}, {"transformationsData": [{"transformation_label": "novalue"}], "feature": "MW _ Hotel Service 1", "transformation": [{"transformation": "novalue", "selectedAsDefault": 1}], "type": "numeric", "replaceby": "mean", "selected": "True", "stats": {"count": "302", "mean": "0.0", "stddev": "0.0", "min": "0", "max": "0", "missing": "0"}, "updatedLabel": "MW _ Hotel Service 1"}, {"transformationsData": [{"transformation_label": "novalue"}], "feature": "MW _ Hotel Service 10", "transformation": [{"transformation": "novalue", "selectedAsDefault": 1}], "type": "numeric", "replaceby": "mean", "selected": "True", "stats": {"count": "302", "mean": "0.0", "stddev": "0.0", "min": "0", "max": "0", "missing": "0"}, "updatedLabel": "MW _ Hotel Service 10"}, {"transformationsData": [{"transformation_label": "novalue"}], "feature": "MW _ Hotel Service 11", "transformation": [{"transformation": "novalue", "selectedAsDefault": 1}], "type": "numeric", "replaceby": "mean", "selected": "True", "stats": {"count": "302", "mean": "0.0", "stddev": "0.0", "min": "0", "max": "0", "missing": "0"}, "updatedLabel": "MW _ Hotel Service 11"}, {"transformationsData": [{"transformation_label": "novalue"}], "feature": "MW _ Hotel Service 12", "transformation": [{"transformation": "novalue", "selectedAsDefault": 1}], "type": "numeric", "replaceby": "mean", "selected": "True", "stats": {"count": "302", "mean": "0.0", "stddev": "0.0", "min": "0", "max": "0", "missing": "0"}, "updatedLabel": "MW _ Hotel Service 12"}, {"transformationsData": [{"transformation_label": "novalue"}], "feature": "MW _ Marketing Service", "transformation": [{"transformation": "novalue", "selectedAsDefault": 1}], "type": "numeric", "replaceby": "mean", "selected": "True", "stats": {"count": "302", "mean": "0.0", "stddev": "0.0", "min": "0", "max": "0", "missing": "0"}, "updatedLabel": "MW _ Marketing Service"}, {"transformationsData": [{"transformation_label": "novalue"}], "feature": "MW Azam Cloud Plus Addon Group", "transformation": [{"transformation": "novalue", "selectedAsDefault": 1}], "type": "numeric", "replaceby": "mean", "selected": "True", "stats": {"count": "302", "mean": "0.0", "stddev": "0.0", "min": "0", "max": "0", "missing": "0"}, "updatedLabel": "MW Azam Cloud Plus Addon ..."}, {"transformationsData": [{"transformation_label": "novalue"}], "feature": "No of Rooms or Points", "transformation": [{"transformation": "novalue", "selectedAsDefault": 1}], "type": "numeric", "replaceby": "mean", "selected": "True", "stats": {"count": "302", "mean": "0.0", "stddev": "0.0", "min": "0", "max": "0", "missing": "0"}, "updatedLabel": "No of Rooms or Points"}, {"transformationsData": [{"transformation_label": "novalue"}], "feature": "PPV Service", "transformation": [{"transformation": "novalue", "selectedAsDefault": 1}], "type": "numeric", "replaceby": "mean", "selected": "True", "stats": {"count": "302", "mean": "1.0", "stddev": "0.06", "min": "0", "max": "1", "missing": "0"}, "updatedLabel": "PPV Service"}, {"transformationsData": [{"transformation_label": "novalue"}], "feature": "Premium (UGD)", "transformation": [{"transformation": "novalue", "selectedAsDefault": 1}], "type": "numeric", "replaceby": "mean", "selected": "True", "stats": {"count": "302", "mean": "0.0", "stddev": "0.0", "min": "0", "max": "0", "missing": "0"}, "updatedLabel": "Premium (UGD)"}, {"transformationsData": [{"transformation_label": "novalue"}], "feature": "Premium Group (KE)", "transformation": [{"transformation": "novalue", "selectedAsDefault": 1}], "type": "numeric", "replaceby": "mean", "selected": "True", "stats": {"count": "302", "mean": "0.0", "stddev": "0.0", "min": "0", "max": "0", "missing": "0"}, "updatedLabel": "Premium Group (KE)"}, {"transformationsData": [{"transformation_label": "novalue"}], "feature": "Premium Group _ TZ", "transformation": [{"transformation": "novalue", "selectedAsDefault": 1}], "type": "numeric", "replaceby": "mean", "selected": "True", "stats": {"count": "302", "mean": "0.18", "stddev": "0.39", "min": "0", "max": "1", "missing": "0"}, "updatedLabel": "Premium Group _ TZ"}, {"transformationsData": [{"transformation_label": "novalue"}], "feature": "RW _ Azam English Service Group", "transformation": [{"transformation": "novalue", "selectedAsDefault": 1}], "type": "numeric", "replaceby": "mean", "selected": "True", "stats": {"count": "302", "mean": "0.0", "stddev": "0.0", "min": "0", "max": "0", "missing": "0"}, "updatedLabel": "RW _ Azam English Service..."}, {"transformationsData": [{"transformation_label": "novalue"}], "feature": "RW _ Plus Group", "transformation": [{"transformation": "novalue", "selectedAsDefault": 1}], "type": "numeric", "replaceby": "mean", "selected": "True", "stats": {"count": "302", "mean": "0.0", "stddev": "0.0", "min": "0", "max": "0", "missing": "0"}, "updatedLabel": "RW _ Plus Group"}, {"transformationsData": [{"transformation_label": "novalue"}], "feature": "RW _ Pure Group", "transformation": [{"transformation": "novalue", "selectedAsDefault": 1}], "type": "numeric", "replaceby": "mean", "selected": "True", "stats": {"count": "302", "mean": "0.0", "stddev": "0.0", "min": "0", "max": "0", "missing": "0"}, "updatedLabel": "RW _ Pure Group"}, {"transformationsData": [{"transformation_label": "novalue"}], "feature": "Religious Service", "transformation": [{"transformation": "novalue", "selectedAsDefault": 1}], "type": "numeric", "replaceby": "mean", "selected": "True", "stats": {"count": "302", "mean": "0.0", "stddev": "0.0", "min": "0", "max": "0", "missing": "0"}, "updatedLabel": "Religious Service"}, {"transformationsData": [{"transformation_label": "novalue"}], "feature": "SL Azam PLay Group", "transformation": [{"transformation": "novalue", "selectedAsDefault": 1}], "type": "numeric", "replaceby": "mean", "selected": "True", "stats": {"count": "302", "mean": "0.0", "stddev": "0.0", "min": "0", "max": "0", "missing": "0"}, "updatedLabel": "SL Azam PLay Group"}, {"transformationsData": [{"transformation_label": "novalue"}], "feature": "TZ _ Azam Plus _ Play Service group", "transformation": [{"transformation": "novalue", "selectedAsDefault": 1}], "type": "numeric", "replaceby": "mean", "selected": "True", "stats": {"count": "302", "mean": "0.09", "stddev": "0.29", "min": "0", "max": "1", "missing": "0"}, "updatedLabel": "TZ _ Azam Plus _ Play Ser..."}, {"transformationsData": [{"transformation_label": "novalue"}], "feature": "TZ _ Lite Service Group", "transformation": [{"transformation": "novalue", "selectedAsDefault": 1}], "type": "numeric", "replaceby": "mean", "selected": "True", "stats": {"count": "302", "mean": "0.77", "stddev": "0.42", "min": "0", "max": "1", "missing": "0"}, "updatedLabel": "TZ _ Lite Service Group"}, {"transformationsData": [{"transformation_label": "novalue"}], "feature": "TZ _ Play Service Group", "transformation": [{"transformation": "novalue", "selectedAsDefault": 1}], "type": "numeric", "replaceby": "mean", "selected": "True", "stats": {"count": "302", "mean": "0.19", "stddev": "0.39", "min": "0", "max": "1", "missing": "0"}, "updatedLabel": "TZ _ Play Service Group"}, {"transformationsData": [{"transformation_label": "novalue"}], "feature": "TZ _ Pure Service Group", "transformation": [{"transformation": "novalue", "selectedAsDefault": 1}], "type": "numeric", "replaceby": "mean", "selected": "True", "stats": {"count": "302", "mean": "0.91", "stddev": "0.28", "min": "0", "max": "1", "missing": "0"}, "updatedLabel": "TZ _ Pure Service Group"}, {"transformationsData": [{"transformation_label": "novalue"}], "feature": "TZ _ WASAFI TV GROUP", "transformation": [{"transformation": "novalue", "selectedAsDefault": 1}], "type": "numeric", "replaceby": "mean", "selected": "True", "stats": {"count": "302", "mean": "0.46", "stddev": "0.5", "min": "0", "max": "1", "missing": "0"}, "updatedLabel": "TZ _ WASAFI TV GROUP"}, {"transformationsData": [{"transformation_label": "novalue"}], "feature": "TZ Azam Cloud Plus Addon Group", "transformation": [{"transformation": "novalue", "selectedAsDefault": 1}], "type": "numeric", "replaceby": "mean", "selected": "True", "stats": {"count": "302", "mean": "0.0", "stddev": "0.0", "min": "0", "max": "0", "missing": "0"}, "updatedLabel": "TZ Azam Cloud Plus Addon ..."}, {"transformationsData": [{"transformation_label": "novalue"}], "feature": "Tikisa Wikiendi", "transformation": [{"transformation": "novalue", "selectedAsDefault": 1}], "type": "numeric", "replaceby": "mean", "selected": "True", "stats": {"count": "302", "mean": "0.0", "stddev": "0.0", "min": "0", "max": "0", "missing": "0"}, "updatedLabel": "Tikisa Wikiendi"}, {"transformationsData": [{"transformation_label": "novalue"}], "feature": "UG _ Azam Play Group", "transformation": [{"transformation": "novalue", "selectedAsDefault": 1}], "type": "numeric", "replaceby": "mean", "selected": "True", "stats": {"count": "302", "mean": "0.0", "stddev": "0.06", "min": "0", "max": "1", "missing": "0"}, "updatedLabel": "UG _ Azam Play Group"}, {"transformationsData": [{"transformation_label": "novalue"}], "feature": "UG _ Azam Pure Group", "transformation": [{"transformation": "novalue", "selectedAsDefault": 1}], "type": "numeric", "replaceby": "mean", "selected": "True", "stats": {"count": "302", "mean": "0.0", "stddev": "0.06", "min": "0", "max": "1", "missing": "0"}, "updatedLabel": "UG _ Azam Pure Group"}, {"feature": "STATUS_stringindexer_transform", "transformation": [{"transformation": "novalue", "selectedAsDefault": 0}], "transformationsData": [{"transformation_label": "novalue"}], "type": "numeric", "selected": "True", "stats": {"count": "302", "mean": "0.29", "stddev": "0.46", "min": "0", "max": "1", "missing": "0"}, "updatedLabel": "STATUS_stringindexer_tran..."}, {"feature": "LAST_UPD_BY_stringindexer_transform", "transformation": [{"transformation": "novalue", "selectedAsDefault": 0}], "transformationsData": [{"transformation_label": "novalue"}], "type": "numeric", "selected": "True", "stats": {"count": "302", "mean": "0.66", "stddev": "0.9", "min": "0", "max": "3", "missing": "0"}, "updatedLabel": "LAST_UPD_BY_stringindexer..."}, {"feature": "STATE_stringindexer_transform", "transformation": [{"transformation": "novalue", "selectedAsDefault": 0}], "transformationsData": [{"transformation_label": "novalue"}], "type": "real", "selected": "True", "stats": {"count": "302", "mean": "1.95", "stddev": "2.03", "min": "0.0", "max": "7.0", "missing": "0"}, "updatedLabel": "STATE_stringindexer_trans..."}, {"feature": "COUNTRY_stringindexer_transform", "transformation": [{"transformation": "novalue", "selectedAsDefault": 0}], "transformationsData": [{"transformation_label": "novalue"}], "type": "numeric", "selected": "True", "stats": {"count": "302", "mean": "0.0", "stddev": "0.06", "min": "0", "max": "1", "missing": "0"}, "updatedLabel": "COUNTRY_stringindexer_tra..."}, {"feature": "DISTRICT_stringindexer_transform", "transformation": [{"transformation": "novalue", "selectedAsDefault": 0}], "transformationsData": [{"transformation_label": "novalue"}], "type": "real", "selected": "True", "stats": {"count": "302", "mean": "0.86", "stddev": "1.0", "min": "0.0", "max": "4.0", "missing": "0"}, "updatedLabel": "DISTRICT_stringindexer_tr..."}, {"feature": "COMPLAINTS_COUNT_stringindexer_transform", "transformation": [{"transformation": "novalue", "selectedAsDefault": 0}], "transformationsData": [{"transformation_label": "novalue"}], "type": "numeric", "selected": "True", "stats": {"count": "302", "mean": "0.04", "stddev": "0.23", "min": "0", "max": "2", "missing": "0"}, "updatedLabel": "COMPLAINTS_COUNT_stringin..."}, {"feature": "DATE_DIFF_FIRST_COMPLAINT_stringindexer_transform", "transformation": [{"transformation": "novalue", "selectedAsDefault": 0}], "transformationsData": [{"transformation_label": "novalue"}], "type": "real", "selected": "True", "stats": {"count": "302", "mean": "1.31", "stddev": "1.24", "min": "0.0", "max": "4.0", "missing": "0"}, "updatedLabel": "DATE_DIFF_FIRST_COMPLAINT..."}, {"feature": "CUSTOMER_AGE_stringindexer_transform", "transformation": [{"transformation": "novalue", "selectedAsDefault": 0}], "transformationsData": [{"transformation_label": "novalue"}], "type": "numeric", "selected": "True", "stats": {"count": "302", "mean": "0.68", "stddev": "0.8", "min": "0", "max": "3", "missing": "0"}, "updatedLabel": "CUSTOMER_AGE_stringindexe..."}, {"feature": "NUMBER_OF_1M_PLANS_stringindexer_transform", "transformation": [{"transformation": "novalue", "selectedAsDefault": 0}], "transformationsData": [{"transformation_label": "novalue"}], "type": "real", "selected": "True", "stats": {"count": "302", "mean": "1.96", "stddev": "1.86", "min": "0.0", "max": "8.0", "missing": "0"}, "updatedLabel": "NUMBER_OF_1M_PLANS_string..."}, {"feature": "TOTAL_RENEWALS_MONTHLY_stringindexer_transform", "transformation": [{"transformation": "novalue", "selectedAsDefault": 0}], "transformationsData": [{"transformation_label": "novalue"}], "type": "real", "selected": "True", "stats": {"count": "302", "mean": "1.16", "stddev": "1.07", "min": "0.0", "max": "4.0", "missing": "0"}, "updatedLabel": "TOTAL_RENEWALS_MONTHLY_st..."}, {"feature": "TOTAL_RENEWALS_WEEKLY_stringindexer_transform", "transformation": [{"transformation": "novalue", "selectedAsDefault": 0}], "transformationsData": [{"transformation_label": "novalue"}], "type": "real", "selected": "True", "stats": {"count": "302", "mean": "1.03", "stddev": "1.35", "min": "0.0", "max": "5.0", "missing": "0"}, "updatedLabel": "TOTAL_RENEWALS_WEEKLY_str..."}, {"feature": "TOTAL_TOPUPS_MONTHLY_stringindexer_transform", "transformation": [{"transformation": "novalue", "selectedAsDefault": 0}], "transformationsData": [{"transformation_label": "novalue"}], "type": "real", "selected": "True", "stats": {"count": "302", "mean": "0.47", "stddev": "0.73", "min": "0.0", "max": "4.0", "missing": "0"}, "updatedLabel": "TOTAL_TOPUPS_MONTHLY_stri..."}, {"feature": "HAVING_TOPUP_stringindexer_transform", "transformation": [{"transformation": "novalue", "selectedAsDefault": 0}], "transformationsData": [{"transformation_label": "novalue"}], "type": "numeric", "selected": "True", "stats": {"count": "302", "mean": "0.36", "stddev": "0.48", "min": "0", "max": "1", "missing": "0"}, "updatedLabel": "HAVING_TOPUP_stringindexe..."}, {"feature": "OPENTITY_TYPE_stringindexer_transform", "transformation": [{"transformation": "novalue", "selectedAsDefault": 0}], "transformationsData": [{"transformation_label": "novalue"}], "type": "numeric", "selected": "True", "stats": {"count": "302", "mean": "0.07", "stddev": "0.25", "min": "0", "max": "1", "missing": "0"}, "updatedLabel": "OPENTITY_TYPE_stringindex..."}]}))

	#transformationPostExecutionHook(autofe)

except Exception as ex: 
	logging.error(ex)

# %% [markdown]
# ***TRAIN MODEL***

# %%
#%run livedatachurnpredictionHooks.ipynb
try:
	#mlPreExecutionHook()

	dataAutoML=functionClassification(autofe, ["CUSTOMER_ID", "STATUS_stringindexer", "LAST_UPD_BY_stringindexer", "STATE_stringindexer", "COUNTRY_stringindexer", "DISTRICT_stringindexer", "COMPLAINTS_COUNT_stringindexer", "DATE_DIFF_FIRST_COMPLAINT_stringindexer", "CUSTOMER_AGE_stringindexer", "NUMBER_OF_1M_PLANS_stringindexer", "TOTAL_RENEWALS_MONTHLY_stringindexer", "TOTAL_RENEWALS_WEEKLY_stringindexer", "TOTAL_TOPUPS_MONTHLY_stringindexer", "HAVING_TOPUP_stringindexer", "DAILY_AVG_SPENDING", "OPENTITY_TYPE_stringindexer", "CA", "CQ", "OP", "PO", "BI _ Azam English Service Group", "BI _ Plus Group", "BI _ Pure Group", "BI Azam Cloud Plus Addon Group", "FTA", "KE _ Azam Demo Group", "KE _ Azam Plus Service Group", "KE _ Azam Pure Service Group", "KE Azam Cloud Plus Addon Group", "MW _ Azam Play Service Group", "MW _ Azam Plus Service Group", "MW _ Azam Pure Service Group", "MW _ Hotel Service 1", "MW _ Hotel Service 10", "MW _ Hotel Service 11", "MW _ Hotel Service 12", "MW _ Marketing Service", "MW Azam Cloud Plus Addon Group", "No of Rooms or Points", "PPV Service", "Premium (UGD)", "Premium Group (KE)", "Premium Group _ TZ", "RW _ Azam English Service Group", "RW _ Plus Group", "RW _ Pure Group", "Religious Service", "SL Azam PLay Group", "TZ _ Azam Plus _ Play Service group", "TZ _ Lite Service Group", "TZ _ Play Service Group", "TZ _ Pure Service Group", "TZ _ WASAFI TV GROUP", "TZ Azam Cloud Plus Addon Group", "Tikisa Wikiendi", "UG _ Azam Play Group", "UG _ Azam Pure Group"], "CHURN_STATUS")

	#mlPostExecutionHook(dataAutoML)

except Exception as ex: 
	logging.error(ex)

# %% [markdown]
# ***PREDICT ON TRAINED MODEL***

# %%
import pandas as pd
import numpy as np
import sklearn.metrics

try:
    model=dataAutoML['model']
    X_test=dataAutoML['X_test']
    y_test=dataAutoML['y_test']
    label=dataAutoML['label']
    columnNames=dataAutoML['columnNames']
    if label in columnNames:
        columnNames.remove(label)
    predicted=label+"_predicted"
    y_predicted=model.predict(X_test)
    df =pd.DataFrame(X_test , columns=columnNames)
    df[label]=y_test
    df[predicted]=y_predicted
    columnNames.insert(0,predicted)
    columnNames.insert(0,label)
    Accuracy = np.round((100 * sklearn.metrics.accuracy_score(y_true=y_test, y_pred=y_predicted)), 1)
    F1= np.round(
            (100 * sklearn.metrics.f1_score(y_true=y_test, y_pred=y_predicted, average="weighted")), 1)
    Precision= np.round((
                100 * sklearn.metrics.precision_score(y_true=y_test, y_pred=y_predicted, average="weighted")), 1)
    Recall = np.round((
                100 * sklearn.metrics.recall_score(y_true=y_test, y_pred=y_predicted, average="weighted")), 1)
    display(" Accuracy of Prediction on test data    : %s"%Accuracy)
    display(" F1 score of Prediction on test data    : %s"%F1)
    display(" Precision of Prediction on test data   : %s"%Precision)
    display(" Recall of Prediction on test data      : %s"%Recall)
    display(df.head())
except Exception as ex:
    logging.error(ex)
